# %%
aa = input ('enter 1st number')
bb = input ('enter 2nd number')
cc = input ('enter 3rd number')
a = float(aa)
b = float(bb)
c = float(cc)
if a > b :
    if a > c :
        print (a, 'is largest')
    else :
        print (c, 'is largest')
else :
    if b > c :
        print (b, 'is largest')
    else :
        print (c, ' is largest')
# Out:
# enter 1st number 1
# enter 2nd number 2
# enter 3rd number 3
# 3.0  is largest
